# %%
# %pip install yfinance pandas matplotlib
# Out:
# Collecting yfinance
#   Downloading yfinance-1.2.1-py2.py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pandas in c:\users\konradchyrzynski\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\konradchyrzynski\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from yfinance) (2.32.2)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-4.0.4-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Collecting curl_cffi>=0.15 (from yfinance)
#   Downloading curl_cffi-0.15.0-cp310-abi3-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from yfinance) (5.29.3)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-16.0-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: soupsieve>1.2 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Collecting cffi>=2.0.0 (from curl_cffi>=0.15->yfinance)
#   Downloading cffi-2.0.0-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from curl_cffi>=0.15->yfinance) (2025.10.5)
# Requirement already satisfied: rich in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from curl_cffi>=0.15->yfinance) (13.3.5)
# Requirement already satisfied: six>=1.5 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: pycparser in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (2.21)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\konradchyrzynski\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->curl_cffi>=0.15->yfinance) (0.1.0)
# Downloading yfinance-1.2.1-py2.py3-none-any.whl (130 kB)
#    ---------------------------------------- 0.0/130.2 kB ? eta -:--:--
#    ------------------ --------------------- 61.4/130.2 kB 1.1 MB/s eta 0:00:01
#    ------------------------------- -------- 102.4/130.2 kB 1.2 MB/s eta 0:00:01
#    -------------------------------------- 130.2/130.2 kB 960.0 kB/s eta 0:00:00
# Downloading curl_cffi-0.15.0-cp310-abi3-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ----- ---------------------------------- 0.2/1.7 MB 4.4 MB/s eta 0:00:01
#    ------------ --------------------------- 0.5/1.7 MB 5.5 MB/s eta 0:00:01
#    ------------------------ --------------- 1.0/1.7 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------  1.7/1.7 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 8.1 MB/s eta 0:00:00
# Downloading peewee-4.0.4-py3-none-any.whl (144 kB)
#    ---------------------------------------- 0.0/144.5 kB ? eta -:--:--
#    ---------------------------------------- 144.5/144.5 kB 8.4 MB/s eta 0:00:00
# Downloading websockets-16.0-cp312-cp312-win_amd64.whl (178 kB)
#    ---------------------------------------- 0.0/178.7 kB ? eta -:--:--
#    ---------------------------------------- 178.7/178.7 kB 5.4 MB/s eta 0:00:00
# Downloading cffi-2.0.0-cp312-cp312-win_amd64.whl (183 kB)
#    ---------------------------------------- 0.0/183.6 kB ? eta -:--:--
#    ---------------------------------------- 183.6/183.6 kB 3.7 MB/s eta 0:00:00
# Building wheels for collected packages: multitasking
#   Building wheel for multitasking (setup.py): started
#   Building wheel for multitasking (setup.py): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15703 sha256=0799aa03aef4c62fec5b186a3f4b7e9b14f8763d5b83d1e732e314fc987fd82f
#   Stored in directory: c:\users\konradchyrzynski\appdata\local\pip\cache\wheels\cc\bd\6f\664d62c99327abeef7d86489e6631cbf45b56fbf7ef1d6ef00
# Successfully built multitasking
# Installing collected packages: peewee, multitasking, websockets, cffi, curl_cffi, yfinance
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.16.0
#     Uninstalling cffi-1.16.0:
#       Successfully uninstalled cffi-1.16.0
# Successfully installed cffi-2.0.0 curl_cffi-0.15.0 multitasking-0.0.12 peewee-4.0.4 websockets-16.0 yfinance-1.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

ticker = "URTH"  # Ticker ETF MSCI World
start_date = "2020-04-07"
end_date = "2026-04-07"

print(f"Downloading data {ticker}...")
data = yf.download(ticker, start=start_date, end=end_date)

data['SMA_50'] = data['Close'].rolling(window=50).mean()
data['SMA_200'] = data['Close'].rolling(window=200).mean()

plt.figure(figsize=(14, 7))

# Drawing closing price
plt.plot(data.index, data['Close'], label='Cena zamknięcia (URTH)', color='black', alpha=0.5, linewidth=1.5)

# Drawing SMA line
plt.plot(data.index, data['SMA_50'], label='SMA 50 dni', color='blue', linewidth=2)
plt.plot(data.index, data['SMA_200'], label='SMA 200 dni', color='red', linewidth=2)

plt.title('MSCI World (Proxy: URTH ETF) - Price and Moving Avg (SMA)', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price (USD)', fontsize=12)
plt.legend(loc='upper left', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Downloading data URTH...
